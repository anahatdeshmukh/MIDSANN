# %%
# Assignment 3
# Recognize document as Positive or Negative using polarity words

from textblob import TextBlob

# Input document
text = input("Enter a sentence: ")

# Find polarity
analysis = TextBlob(text)

polarity = analysis.sentiment.polarity

# Check sentiment
if polarity > 0:
    print("Positive Document")
elif polarity < 0:
    print("Negative Document")
else:
    print("Neutral Document")

# Display polarity value
print("Polarity Score:", polarity)
# Out:
# Negative Document
# Polarity Score: -0.6999999999999998

# %% [markdown]
# pip install textblob
# example: I really love this product
# Positive Document
# Polarity Score: 0.5
