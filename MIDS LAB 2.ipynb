# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report

# Load dataset
df = pd.read_csv("twitter.csv")

# Remove rows with missing target values
df.dropna(subset=['label'], inplace=True)

# Input and output
X = df['tweet']
y = df['label']

# Convert text into numerical vectors
vectorizer = TfidfVectorizer()

X_vectorized = vectorizer.fit_transform(X.fillna(''))

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X_vectorized,
    y,
    test_size=0.2,
    random_state=42
)

# Apply KNN
knn = KNeighborsClassifier(n_neighbors=5)

# Train model
knn.fit(X_train, y_train)

# Prediction on test data
y_pred = knn.predict(X_test)

# Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred))

# Report
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))

# New custom sentence
new_data = ["pm modi's tenure was very bad"]

# Convert into vector
new_vectorizer = vectorizer.transform(new_data)

# Predict sentiment
prediction = knn.predict(new_vectorizer)

print("\nPrediction:", prediction)
# Out:
# Accuracy: 0.9472860941654935
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      5937
#            1       0.95      0.27      0.43       456
#
#     accuracy                           0.95      6393
#    macro avg       0.95      0.64      0.70      6393
# weighted avg       0.95      0.95      0.93      6393
#
#
# Prediction: [0]
